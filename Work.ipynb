# %%
# %pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\deyvi\downloads\ia center - centro de datos\clase 11\webbosch\.env\lib\site-packages (4.9.3)
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup
import requests
import os
CARPETA_DESTINO ='jobs/'
with open("page/Vacantes en Bosch Group.html", "r", encoding="utf-8") as file:
    content = file.read()
soup = BeautifulSoup(content, 'lxml')
job_listings = []

job_sections = soup.find_all('section', {'class': 'openings-section opening opening--grouped js-group'})
job_sections
# Out:
# [<section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Aguascalientes, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999906794539-purchasing-quality-automotive-manager?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Purchasing Quality Automotive manager</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Apaseo el Grande, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999916479723-ingeniero-mantenimiento-a-edificios?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero Mantenimiento a Edificios</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="3"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Cd. Juárez, México</h3></li><li><span class="title">3 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999913390523-test-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">TEST ENGINEER</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999902492886-ingeniero-de-ventas-automatizacion-ciudad-juarez-?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de Ventas Automatizaciòn (Ciudad Juarez)</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999855572249-ingeniero-de-diseno-de-hardware?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de Diseño de Hardware</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="31"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Celaya, México</h3></li><li><span class="title">31 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919081539-ingeniero-de-de-procesos-mecanicos-manufactura?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de de procesos mecánicos || Manufactura</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919081183-ingeniero-de-procesos-para-dispensado-proyectos?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de procesos para dispensado || Proyectos</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919075433-ingeniero-de-procesos-mecanicos-mfp?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de procesos mecánicos || MFP</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919069284-ingeniero-de-procesos-mecanicos-proyectos?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de procesos mecánicos || Proyectos</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919065123-ingeniero-de-procesos-mecanicos-manufactura-b?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero de procesos mecánicos|| Manufactura B</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999918083128-hr-associate-labor-relations?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">HR Associate- Labor relations</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999914439026-gerente-de-smt?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Gerente de SMT</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999912957513-coordinador-de-producto?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Coordinador de Producto</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999912957183-supervisor-de-mantenimiento? ...
#  <section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Chihuahua, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999908597283-asesor-comercial-?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Asesor Comercial..</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="49"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Ciudad Juárez, México</h3></li><li><span class="title">49 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999917862352-coordinacion-de-cadena-de-suministro-c-tpat-y-oea?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Coordinación de Cadena de Suministro C-TPAT y OEA</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999916196133-traffic-generalist?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Traffic Generalist</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999916195048-traffic-coordinator?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Traffic Coordinator</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999915934983-tecnico-de-mantenimiento-de-equipo?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Tecnico de mantenimiento de equipo</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999915694048-project-coordinator?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">PROJECT COORDINATOR</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999915647333-quality-assurance-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">QUALITY ASSURANCE ENGINEER</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999915450943-tecnico-mecanico-de-montaje?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Técnico Mecánico de Montaje</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999914761973-especialista-de-comunicacion?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Especialista de Comunicacion</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span><i class="icon icon--l icon--material-earth" title="Los empleados pueden trabajar de forma remota"></i></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999913391113-process-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f ...
#  <section class="openings-section opening opening--grouped js-group" data-qty="5"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Ciudad Juarez, México</h3></li><li><span class="title">5 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999918575363-navigator-of-lean-management?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Navigator of Lean Management</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999917116213-it-security-analyst?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">IT Security Analyst</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999917115043-it-security-consultant?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">IT Security Consultant</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999909953863-coordinador-de-contabilidad?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Coordinador de Contabilidad</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</
span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999914799523-manufacturing-and-technical-functions-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Manufacturing and Technical Functions Engineer</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999914743573-logistic-expert-allocation-command-center?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Logistic Expert Allocation - Command Center</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999913872153-logistic-specialist?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Logistic Specialist</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999913601613-procurement-planner-supervisor?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Procurement Planner Supervisor</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999896794308-tecnico-mecanico-de-montaje?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Técnico Mecánico de Montaje</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Tequisquiapan, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999909997593-responsable-de-ensamble-en-construccion-de-maquinas?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Responsable de Ensamble en Construccion de Maquinas</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="30"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Toluca de Lerdo, México</h3></li><li><span class="title">30 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919262873-analista-de-aduanas?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Analista de Aduanas</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919246563-failure-management-quality-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Failure Management Quality Engineer</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919234623-manufacture-and-process-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Manufacture and Process Engineer</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999919081943-traffic-specialist-temporary-?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Traffic Specialist (Temporary)</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999918757213-project-administrator?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Project Administrator</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999918617918-analista-de-empaque-y-trafico?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Analista de Empaque y Trafico</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999917861813-project-leader?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Project Leader</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999917086903-ingeniero-a-de-proyecto-construccion-de-maquinaria?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Ingeniero/a de Proyecto, Construcción de maquinaria</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999916848133-launch-engineer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Launch Engineer</h ...
#  <section class="openings-section opening opening--grouped js-group" data-qty="3"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Toluca, México</h3></li><li><span class="title">3 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999917118443-information-security-risk-and-compliance-analyst?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Information Security Risk and Compliance Analyst</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999912753553-it-support-analyst?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">IT Support Analyst</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999876904583-automotive-commodity-buyer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Automotive Commodity Buyer</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="2"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Tonalá, México</h3></li><li><span class="title">2 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999916093734-sap-controlling-consultant?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">SAP Controlling Consultant</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999869849072-web-developer-jr-net-c-?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Web Developer Jr - .Net C#</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="2"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Zapopan, México</h3></li><li><span class="title">2 empleos</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999906522357-qa-leader?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">QA Leader</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999769600886-embedded-software-developer?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Embedded Software Developer</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">Zumpango de Ocampo, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999914488412-supervisor-de-linea?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Supervisor de Línea</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">juarez, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999907904773-tecnico-desarrollador-de-aplicaciones?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">Técnico Desarrollador de Aplicaciones</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>,
#  <section class="openings-section opening opening--grouped js-group" data-qty="1"><header class="opening-header"><ul class="list--dotted title-list"><li><h3 class="opening-title title display--inline-block text--default">nuevo leon, México</h3></li><li><span class="title">1 empleo</span></li></ul></header><ul class="opening-jobs grid--gutter padding--none js-group-list"><li class="opening-job job column wide-7of16 medium-1of2"><a class="link--block details" href="https://jobs.smartrecruiters.com/BoschGroup/743999913815243-sqe-metal-parts?trid=c2ad57d8-2ec6-41b0-aac8-9fb2f04e9fa5"><h4 class="details-title job-title link--block-target">SQE Metal Parts</h4><p class="details-desc job-desc"><span class="margin--right--s">Jornada completa</span></p></a></li></ul></section>]

# %%
def limpiar_nombre_archivo(nombre):
    '''Limpiar caracteres no permitidos en nombres de archivos.'''
    caracteres_invalidos = ['<', '>', ':', '"', '/', '\\', '|', '?', '*']
    for char in caracteres_invalidos:
        nombre = nombre.replace(char, '-')
    return nombre

# %%
# Now you can loop over the sections and extract the details for each job
for section in job_sections:
    location = section.find('h3', {'class': 'opening-title title display--inline-block text--default'}).text
    jobs = section.find_all('li', {'class': 'opening-job job column wide-7of16 medium-1of2'})
    for job in jobs:
        job_link = job.find('a')['href']
        job_title = job.find('h4', {'class': 'details-title job-title link--block-target'}).text


        job_response = requests.get( job_link)
        if job_response.status_code == 200:
                    job_title=limpiar_nombre_archivo(job_title)
                    filename = os.path.join(CARPETA_DESTINO, job_title + ".html")
                    # Guarda el contenido en un archivo .html
                   # with open(filename, 'w', encoding='utf-8') as f:
f.write(job_response.text)
                    #else:
print(f"No se pudo descargar el trabajo: {job_title}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 10
#       6 job_link = job.find('a')['href']
#       7 job_title = job.find('h4', {'class': 'details-title job-title link--block-target'}).text
# ---> 10 job_response = requests.get( job_link)
#      11 if job_response.status_code == 200:
#      12             job_title=limpiar_nombre_archivo(job_title)
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\deyvi\Downloads\IA Center - Centro de datos\Clase 11\webBosch\.env\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File C:\Python 3.11\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File C:\Python 3.11\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Python 3.11\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Python 3.11\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Python 3.11\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Python 3.11\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from glob import glob
from bs4 import BeautifulSoup

path = 'jobs/*.html'
files = glob(path)

for file in files:
    print(file)
with open(file, 'r', encoding='utf-8') as f:
        content = f.read()
soup = BeautifulSoup(content, 'lxml')
    
    # Título del trabajo
try:
        job_title = soup.find('h1', class_='job-title').text.strip()
        print("Título del trabajo:", job_title)
except AttributeError:
        print("No se encontró el título del trabajo")

    # Ubicación del trabajo
try:
        job_location = soup.find('span', class_='job-detail').text.strip()
        print("Ubicación del trabajo:", job_location)
except AttributeError:
        print("No se encontró la ubicación del trabajo")

    # Tipo de empleo
try:
        employment_type = soup.find('li', itemprop='employmentType').text.strip()
        print("Tipo de empleo:", employment_type)
except AttributeError:
        print("No se encontró el tipo de empleo")

    # Entidad legal
try:
        legal_entity = soup.find('li', class_='job-detail').text.strip()
        print("Entidad Legal:", legal_entity)
except AttributeError:
        print("No se encontró la entidad legal")

    # Descripción del trabajo
try:
        job_description = soup.find('div', itemprop='description').text.strip()
        print("Descripción del trabajo:")
        print(job_description)
except AttributeError:
        print("No se encontró la descripción del trabajo")

    # Calificaciones/Requisitos
try:
        qualifications = soup.find('div', itemprop='qualifications').find_all('li')
        print("Calificaciones/Requisitos:")
        for qualification in qualifications:
            print("-", qualification.text.strip())
except AttributeError:
        print("No se encontraron las calificaciones/requisitos")

    # Información adicional
try:
        additional_information = soup.find('div', itemprop='f').text.strip()
        print("Información adicional:")
        print(additional_information)
except AttributeError:
        print("No se encontró información adicional")

print()  # Salto de línea pa
